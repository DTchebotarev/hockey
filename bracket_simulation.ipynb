# %%
# !conda install matplotlib -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/nbuser/anaconda3_501
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     python-3.6.3               |       h6c0c0dc_5        29.0 MB
#     numpy-1.14.2               |   py36hdbf6ddf_0         4.0 MB
#     wheel-0.31.0               |           py36_0          62 KB
#     sip-4.19.8                 |   py36hf484d3e_0         290 KB
#     certifi-2018.1.18          |           py36_0         144 KB
#     matplotlib-2.1.2           |   py36h0e671d2_0         6.7 MB
#     sqlite-3.20.1              |       hb898158_2         1.5 MB
#     tornado-5.0.1              |           py36_1         641 KB
#     python-dateutil-2.7.2      |           py36_0         256 KB
#     setuptools-39.0.1          |           py36_0         549 KB
#     pip-9.0.3                  |           py36_0         2.3 MB
#     pytz-2018.3                |           py36_0         212 KB
#     readline-7.0               |       ha6073c6_4         1.1 MB
#     ------------------------------------------------------------
#                                            Total:        46.6 MB
#
# The following NEW packages will be INSTALLED:
#
#     readline:        7.0-ha6073c6_4
#
# The following packages will be UPDATED:
#
#     certifi:         2017.7.27.1-py36h8b7b77e_0             --> 2018.1.18-py36_0
#     matplotlib:      2.1.1-py36_2               conda-forge --> 2.1.2-py36h0e671d2_0
#     numpy:           1.12.1-py36he24570b_1                  --> 1.14.2-py36hdbf6ddf_0
#     pip:             9.0.1-py36h8ec8b28_3                   --> 9.0.3-py36_0
#     python:          3.6.3-h0ef2715_3                       --> 3.6.3-h6c0c0dc_5
#     python-dateutil: 2.6.1-py36h88d3b88_1                   --> 2.7.2-py36_0
#     pytz:            2017.2-py36hc2ccc2a_1                  --> 2018.3-py36_0
#     setuptools:      36.5.0-py36he42e2e1_0                  --> 39.0.1-py36_0
#     sip:             4.18.1-py36h51ed4ed_2                  --> 4.19.8-py36hf484d3e_0
#     sqlite:          3.20.1-0                   conda-forge --> 3.20.1-hb898158_2
#     tornado:         4.5.2-py36h1283b2a_0                   --> 5.0.1-py36_1
#     wheel:           0.29.0-py36he7f4e38_1                  --> 0.31.0-py36_0
#
#
# Downloading and Extracting Packages
# python 3.6.3: ########################################################## | 100%
# numpy 1.14.2: ########################################################## | 100%
# wheel 0.31.0: ########################################################## | 100%
# sip 4.19.8: ############################################################ | 100%
# certifi 2018.1.18: ##################################################### | 100%
# matplotlib 2.1.2: ###################################################### | 100%
# sqlite 3.20.1: ######################################################### | 100%
# tornado 5.0.1: ######################################################### | 100%
# python-dateutil 2.7.2: ################################################# | 100%
# setuptools 39.0.1: ##################################################### | 100%
# pip 9.0.3: ############################################################# | 100%
# pytz 2018.3: ########################################################### | 100%
# readline 7.0: ########################################################## | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import pandas as pd

# %%
# %matplotlib inline
pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %%
player_df = pd.read_pickle('player_dfidual.pickle')

# %%
elo_scores = pd.read_html('http://morehockeystats.com/teams/elo?inline=1&season=2017&page=1&hl=',index_col=0,header=0)[0]

# %%
elo_scores
# Out:
#                      Team  Div      Elo  Pts  Gin7  Pin7  Tin7  Gin30  Pin30  \
# #
# 1     Nashville Predators  CEN  2370.68  115     1     1   116      1      1
# 2     Tampa Bay Lightning  ATL  2281.09  112     1     2   114      1      2
# 3           Winnipeg Jets  CEN  2393.73  112     1     2   114      1      2
# 4           Boston Bruins  ATL  2318.62  110     2     3   113      2      3
# 5    Vegas Golden Knights  PAC  2264.26  109     1     2   111      1      2
# 6     Toronto Maple Leafs  ATL  2291.78  103     1     2   105      1      2
# 7     Washington Capitals  MET  2290.91  103     1     1   104      1      1
# 8         San Jose Sharks  PAC  2246.34  100     1     1   101      1      1
# 9          Minnesota Wild  CEN  2285.87   99     1     1   100      1      1
# 10    Pittsburgh Penguins  MET  2302.67  100     0     0   100      0      0
# 11          Anaheim Ducks  PAC  2347.86   99     1     1   100      1      1
# 12      Los Angeles Kings  PAC  2295.57   98     1     1    99      1      1
# 13  Columbus Blue Jackets  MET  2327.08   97     1     1    98      1      1
# 14    Philadelphia Flyers  MET  2259.65   96     1     2    98      1      2
# 15      New Jersey Devils  MET  2328.59   97     1     1    98      1      1
# 16       Florida Panthers  ATL  2326.02   92     2     3    95      2      3
# 17        St. Louis Blues  CEN  2229.44   94     1     1    95      1      1
# 18     Colorado Avalanche  CEN  2173.96   93     1     1    94      1      1
# 19           Dallas Stars  CEN  2174.67   90     1     1    91      1      1
# 20         Calgary Flames  PAC  2056.87   82     1     1    83      1      1
# 21    Carolina Hurricanes  MET  2125.97   81     1     1    82      1      1
# 22     New York Islanders  MET  2096.92   78     1     1    79      1      1
# 23       New York Rangers  MET  2098.40   77     1     1    78      1      1
# 24        Edmonton Oilers  PAC  2180.22   76     1     1    77      1      1
# 25     Chicago Blackhawks  CEN  2129.55   76     1     0    76      1      0
# 26      Detroit Red Wings  ATL  2095.78   72     1     1    73      1      1
# 27      Vancouver Canucks  PAC  2206.08   72     1     1    73      1      1
# 28     Montreal Canadiens  ATL  2116.21   71     1     1    72      1      1
# 29        Arizona Coyotes  PAC  2260.49   70     1     1    71      1      1
# 30        Ottawa Senators  ATL  2058.30   67     1     0    67      1      0
# 31         Buffalo Sabres  ATL  2098.42   62     1     0    62      1      0
#
#     Tin30  GinS  PinS  TinS
# #
# 1     116     1     1   116
# 2     114     1     2   114
# 3     114     1     2   114
# 4     113     2     3   113
# 5     111     1     2   111
# 6     105     1     2   105
# 7     104     1     1   104
# 8     101     1     1   101
# 9     100     1     1   100
# 10    100     0     0   100
# 11    100     1     1   100
# 12     99     1     1    99
# 13     98     1     1    98
# 14     98     1     2    98
# 15     98     1     1    98
# 16     95     2     3    95
# 17     95     1     1    95
# 18     94     1     1    94
# 19     91     1     1    91
# 20     83     1     1    83
# 21     82     1     1    82
# 22     79     1     1    79
# 23     78     1     1    78
# 24     77     1     1    77
# 25     76     1     0    76
# 26     73     1     1    73
# 27     73     1     1    73
# 28     72     1     1    72
# 29     71     1     1    71
# 30     67     1     0    67
# 31     62     1     0    62
